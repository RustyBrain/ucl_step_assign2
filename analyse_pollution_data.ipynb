# %%
import pandas as pd

# %%
df = pd.read_csv('outputs/pollution_city_comparison.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-eecf7c553d9a> in <module>
# ----> 1 df = pd.read_csv('outputs/pollution_city_comparison.csv', index=False)
#
# TypeError: parser_f() got an unexpected keyword argument 'index'

# %%
df
# Out:
#      Unnamed: 0                   city       high        low measurement  \
# 0             0                 London  18.303353  20.640991       µg/m3
# 1             1                 London  20.652493  17.510204       µg/m3
# 2             2                 London  26.618444  21.602564       µg/m3
# 3             3                 London        NaN        NaN       µg/m3
# 4             4                 London        NaN        NaN       µg/m3
# ..          ...                    ...        ...        ...         ...
# 987         987  Frankfurt%20am%20Main        NaN        NaN       µg/m3
# 988         988  Frankfurt%20am%20Main        NaN        NaN       µg/m3
# 989         989  Frankfurt%20am%20Main        NaN        NaN       µg/m3
# 990         990  Frankfurt%20am%20Main        NaN        NaN       µg/m3
# 991         991  Frankfurt%20am%20Main        NaN        NaN       µg/m3
#
#       midnight pollutant             site    year
# ...

# %%
city_by_year = df.groupby(['city', 'measurement', 'pollutant', 'year'], as_index=False).mean()
city_by_year
# Out:
#           city measurement   pollutant    year  Unnamed: 0       high  \
# 0    Amsterdam    ugNO2/m3  NOX as NO2  2016.0       290.0  60.265750
# 1    Amsterdam    ugNO2/m3  NOX as NO2  2017.0       301.0  55.247506
# 2    Amsterdam    ugNO2/m3  NOX as NO2  2018.0       312.0  49.058345
# 3    Amsterdam       µg/m3         NO2  2016.0       323.0  32.507951
# 4    Amsterdam       µg/m3         NO2  2017.0       334.0  31.942974
# ..         ...         ...         ...     ...         ...        ...
# 99       Paris       µg/m3        PM10  2019.0       488.5        NaN
# 100      Paris       µg/m3       PM2.5  2016.0       495.5  13.790492
# 101      Paris       µg/m3       PM2.5  2017.0       501.5  12.243917
# 102      Paris       µg/m3       PM2.5  2018.0       507.5  12.730699
# 103      Paris       µg/m3       PM2.5  2019.0       513.5        NaN
#
#            low   midnight
# 0    39.090159  49.848555
# 1    36.739689  44.948366
# 2    32.692049  40.245333
# ...
